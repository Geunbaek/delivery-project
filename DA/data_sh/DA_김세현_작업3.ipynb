# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
food = pd.read_csv('/content/drive/MyDrive/seoul_food.csv')

# %%
weather = pd.read_csv('/content/drive/MyDrive/20_seoul_weather.csv', encoding='cp949')

# %%
food.head(30)
# Out:
#           date  hour    food district  count
# 0   2020-01-01     0      분식      관악구      2
# 1   2020-01-01     0      분식      구로구      1
# 2   2020-01-01     0      분식      금천구      2
# 3   2020-01-01     0      분식      노원구      8
# 4   2020-01-01     0      야식      구로구      4
# 5   2020-01-01     0      야식      금천구     18
# 6   2020-01-01     0      야식      도봉구      1
# 7   2020-01-01     0      야식      양천구      1
# 8   2020-01-01     0      야식     영등포구      4
# 9   2020-01-01     0   족발/보쌈      구로구     10
# 10  2020-01-01     0   족발/보쌈      금천구      4
# 11  2020-01-01     0   족발/보쌈     영등포구      1
# 12  2020-01-01     0   족발/보쌈      은평구     12
# 13  2020-01-01     0      찜탕      구로구      1
# 14  2020-01-01     0      찜탕      금천구      1
# 15  2020-01-01     0      찜탕      도봉구      1
# 16  2020-01-01     0      치킨      강북구      9
# 17  2020-01-01     0      치킨      관악구      9
# 18  2020-01-01     0      치킨      구로구     25
# 19  2020-01-01     0      치킨      금천구     18
# ...

# %%
food.head(100)
# Out:
#           date  hour food district  count
# 0   2020-01-01     0   분식      관악구      2
# 1   2020-01-01     0   분식      구로구      1
# 2   2020-01-01     0   분식      금천구      2
# 3   2020-01-01     0   분식      노원구      8
# 4   2020-01-01     0   야식      구로구      4
# ..         ...   ...  ...      ...    ...
# 95  2020-01-01    10   한식      구로구      2
# 96  2020-01-01    10   한식      금천구      2
# 97  2020-01-01    10   한식      도봉구      2
# 98  2020-01-01    10   한식     영등포구      5
# 99  2020-01-01    11  도시락      양천구      1
#
# [100 rows x 5 columns]

# %%
weather
# Out:
#        지점 지점명                일시  기온(°C)  강수량(mm)
# 0     108  서울  2020-01-01 00:00    -6.5      0.0
# 1     108  서울  2020-01-01 01:00    -5.9      NaN
# 2     108  서울  2020-01-01 02:00    -5.7      NaN
# 3     108  서울  2020-01-01 03:00    -5.6      0.0
# 4     108  서울  2020-01-01 04:00    -5.4      NaN
# ...   ...  ..               ...     ...      ...
# 8778  108  서울  2020-12-31 19:00    -7.1      NaN
# 8779  108  서울  2020-12-31 20:00    -7.1      NaN
# 8780  108  서울  2020-12-31 21:00    -7.2      NaN
# 8781  108  서울  2020-12-31 22:00    -7.4      NaN
# 8782  108  서울  2020-12-31 23:00    -7.6      NaN
#
# [8783 rows x 5 columns]

# %%
food.drop(columns='district')
# Out:
#               date  hour food  count
# 0       2020-01-01     0   분식      2
# 1       2020-01-01     0   분식      1
# 2       2020-01-01     0   분식      2
# 3       2020-01-01     0   분식      8
# 4       2020-01-01     0   야식      4
# ...            ...   ...  ...    ...
# 401534  2020-12-31    23   한식      3
# 401535  2020-12-31    23    회      1
# 401536  2020-12-31    23    회      6
# 401537  2020-12-31    23    회      1
# 401538  2020-12-31    23    회      5
#
# [401539 rows x 4 columns]

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401539 entries, 0 to 401538
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   date      401539 non-null  object
#  1   hour      401539 non-null  int64
#  2   food      401539 non-null  object
#  3   district  401539 non-null  object
#  4   count     401539 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 15.3+ MB

# %%
food_division = food.groupby(['date', 'hour', 'food']).sum()

# %%
food_division.reset_index(inplace=True)

# %%
food_division
# Out:
#              date  hour    food  count
# 0      2020-01-01     0      분식     13
# 1      2020-01-01     0      야식     28
# 2      2020-01-01     0   족발/보쌈     27
# 3      2020-01-01     0      찜탕      3
# 4      2020-01-01     0      치킨    103
# ...           ...   ...     ...    ...
# 87901  2020-12-31    23  카페/디저트     32
# 87902  2020-12-31    23   패스트푸드     25
# 87903  2020-12-31    23      피자     24
# 87904  2020-12-31    23      한식     28
# 87905  2020-12-31    23       회     13
#
# [87906 rows x 4 columns]

# %%
food_division['date'] = pd.to_datetime(food_division['date'])

# %%
food_division
# Out:
#             date  hour    food  count
# 0     2020-01-01     0      분식     13
# 1     2020-01-01     0      야식     28
# 2     2020-01-01     0   족발/보쌈     27
# 3     2020-01-01     0      찜탕      3
# 4     2020-01-01     0      치킨    103
# ...          ...   ...     ...    ...
# 87901 2020-12-31    23  카페/디저트     32
# 87902 2020-12-31    23   패스트푸드     25
# 87903 2020-12-31    23      피자     24
# 87904 2020-12-31    23      한식     28
# 87905 2020-12-31    23       회     13
#
# [87906 rows x 4 columns]

# %%
food_division.head(50)
# Out:
#          date  hour    food  count
# 0  2020-01-01     0      분식     13
# 1  2020-01-01     0      야식     28
# 2  2020-01-01     0   족발/보쌈     27
# 3  2020-01-01     0      찜탕      3
# 4  2020-01-01     0      치킨    103
# 5  2020-01-01     0  카페/디저트      1
# 6  2020-01-01     0      피자     14
# 7  2020-01-01     0      한식      2
# 8  2020-01-01     0       회     15
# 9  2020-01-01     1  돈까스/일식      1
# 10 2020-01-01     1      분식      5
# 11 2020-01-01     1      야식      5
# 12 2020-01-01     1   족발/보쌈     19
# 13 2020-01-01     1      찜탕      1
# 14 2020-01-01     1      치킨     62
# 15 2020-01-01     1  카페/디저트      3
# 16 2020-01-01     1      피자      3
# 17 2020-01-01     1      한식      3
# 18 2020-01-01     1       회      3
# 19 2020-01-01     2  돈까스/일식      4
# 20 2020-01-01     2      야식      2
# 21 2020-01-01     2      치킨     19
# 22 2020-01-01     2      피자      1
# 23 2020-01-01     2      한식      1
# 24 2020-01-01     2       회      1
# 25 2020-01-01     9      치킨      1
# ...

# %%
weather['일시'] = pd.to_datetime(weather['일시'])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
weather['일시'].dt.hour
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#         ..
# 8778    19
# 8779    20
# 8780    21
# 8781    22
# 8782    23
# Name: 일시, Length: 8783, dtype: int64

# %%
weather['시간'] = weather['일시'].dt.hour
weather['날짜'] = weather['일시'].dt.date

# %%
weather
# Out:
#        지점 지점명                  일시  기온(°C)  강수량(mm)  시간          날짜
# 0     108  서울 2020-01-01 00:00:00    -6.5      0.0   0  2020-01-01
# 1     108  서울 2020-01-01 01:00:00    -5.9      NaN   1  2020-01-01
# 2     108  서울 2020-01-01 02:00:00    -5.7      NaN   2  2020-01-01
# 3     108  서울 2020-01-01 03:00:00    -5.6      0.0   3  2020-01-01
# 4     108  서울 2020-01-01 04:00:00    -5.4      NaN   4  2020-01-01
# ...   ...  ..                 ...     ...      ...  ..         ...
# 8778  108  서울 2020-12-31 19:00:00    -7.1      NaN  19  2020-12-31
# 8779  108  서울 2020-12-31 20:00:00    -7.1      NaN  20  2020-12-31
# 8780  108  서울 2020-12-31 21:00:00    -7.2      NaN  21  2020-12-31
# 8781  108  서울 2020-12-31 22:00:00    -7.4      NaN  22  2020-12-31
# 8782  108  서울 2020-12-31 23:00:00    -7.6      NaN  23  2020-12-31
#
# [8783 rows x 7 columns]

# %%
food_division['Celsius'] = 0
food_division['rain'] = 0

# %%
food_division, weather
# Out:
# (            date  hour    food  count  Celsius  rain
#  0     2020-01-01     0      분식     13        0     0
#  1     2020-01-01     0      야식     28        0     0
#  2     2020-01-01     0   족발/보쌈     27        0     0
#  3     2020-01-01     0      찜탕      3        0     0
#  4     2020-01-01     0      치킨    103        0     0
#  ...          ...   ...     ...    ...      ...   ...
#  87901 2020-12-31    23  카페/디저트     32        0     0
#  87902 2020-12-31    23   패스트푸드     25        0     0
#  87903 2020-12-31    23      피자     24        0     0
#  87904 2020-12-31    23      한식     28        0     0
#  87905 2020-12-31    23       회     13        0     0
#
#  [87906 rows x 6 columns],
#         지점 지점명                  일시  기온(°C)  강수량(mm)  시간          날짜
#  0     108  서울 2020-01-01 00:00:00    -6.5      0.0   0  2020-01-01
#  1     108  서울 2020-01-01 01:00:00    -5.9      NaN   1  2020-01-01
#  2     108  서울 2020-01-01 02:00:00    -5.7      NaN   2  2020-01-01
# ...

# %%
food_division.iloc[1][1]
# Out:
# 0

# %%
len(food_division)
# Out:
# 87906

# %%
# 8억번 연산. 매우 비효율적(멍청한짓)
# from numpy.core.numeric import NaN
# for i in range(len(food_division)):
#     for j in range(len(weather)):
#         if  food_division.iloc[i][0] == weather.iloc[j][6] and food_division.iloc[i][1] == weather.iloc[j][5]:
#             try:
#                 food_division.iloc[i][4] = weather[j][3]
#                 food_division.iloc[i][5] = weather[j][4]
#             except:
#                  food_division.iloc[i][4] = NaN
#                  food_division.iloc[i][5] = NaN

# %%
food_division.drop(columns={'Celsius', 'rain'})
# Out:
#             date  hour    food  count
# 0     2020-01-01     0      분식     13
# 1     2020-01-01     0      야식     28
# 2     2020-01-01     0   족발/보쌈     27
# 3     2020-01-01     0      찜탕      3
# 4     2020-01-01     0      치킨    103
# ...          ...   ...     ...    ...
# 87901 2020-12-31    23  카페/디저트     32
# 87902 2020-12-31    23   패스트푸드     25
# 87903 2020-12-31    23      피자     24
# 87904 2020-12-31    23      한식     28
# 87905 2020-12-31    23       회     13
#
# [87906 rows x 4 columns]

# %%
weather2 = weather

# %%
weather2 = weather2.drop(columns={'지점', '지점명', '일시'})

# %%
cols = weather2.columns.tolist()
cols
# Out:
# ['기온(°C)', '강수량(mm)', '시간', '날짜']

# %%
cols = cols[-1:] + cols[:-1]
cols = cols[-1:] + cols[:-1]

# %%
cols[1]
# Out:
# '날짜'

# %%
cols = [cols[1]]+[cols[0]]+[cols[2]]+[cols[3]]

# %%
cols
# Out:
# ['날짜', '시간', '기온(°C)', '강수량(mm)']

# %%
cols
# Out:
# ['날짜', '시간', '기온(°C)', '강수량(mm)']

# %%
weather2 = weather2[cols]

# %%
weather2 = weather2.rename(columns={'날짜':'date', '시간':'hour', '기온(°C)':'celsius(C)', '강수량(mm)':'rain(mm)'})

# %%
weather2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8783 entries, 0 to 8782
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        8783 non-null   object
#  1   hour        8783 non-null   int64
#  2   celsius(C)  8783 non-null   float64
#  3   rain(mm)    1061 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 274.6+ KB

# %%
food_division.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87906 entries, 0 to 87905
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     87906 non-null  datetime64[ns]
#  1   hour     87906 non-null  int64
#  2   food     87906 non-null  object
#  3   count    87906 non-null  int64
#  4   Celsius  87906 non-null  int64
#  5   rain     87906 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 4.0+ MB

# %%
weather2['date'] = pd.to_datetime(weather2['date'])

# %%
weather2
# Out:
#            date  hour  celsius(C)  rain(mm)
# 0    2020-01-01     0        -6.5       0.0
# 1    2020-01-01     1        -5.9       NaN
# 2    2020-01-01     2        -5.7       NaN
# 3    2020-01-01     3        -5.6       0.0
# 4    2020-01-01     4        -5.4       NaN
# ...         ...   ...         ...       ...
# 8778 2020-12-31    19        -7.1       NaN
# 8779 2020-12-31    20        -7.1       NaN
# 8780 2020-12-31    21        -7.2       NaN
# 8781 2020-12-31    22        -7.4       NaN
# 8782 2020-12-31    23        -7.6       NaN
#
# [8783 rows x 4 columns]

# %%
food_weather = pd.merge(food_division, weather2, on=['date', 'hour'])

# %%
food_weather['rain(mm)'] = food_weather['rain(mm)'].fillna(0.0)

# %%
food_weather
# Out:
#             date  hour    food  count  Celsius  rain  celsius(C)  rain(mm)
# 0     2020-01-01     0      분식     13        0     0        -6.5       0.0
# 1     2020-01-01     0      야식     28        0     0        -6.5       0.0
# 2     2020-01-01     0   족발/보쌈     27        0     0        -6.5       0.0
# 3     2020-01-01     0      찜탕      3        0     0        -6.5       0.0
# 4     2020-01-01     0      치킨    103        0     0        -6.5       0.0
# ...          ...   ...     ...    ...      ...   ...         ...       ...
# 87888 2020-12-31    23  카페/디저트     32        0     0        -7.6       0.0
# 87889 2020-12-31    23   패스트푸드     25        0     0        -7.6       0.0
# 87890 2020-12-31    23      피자     24        0     0        -7.6       0.0
# 87891 2020-12-31    23      한식     28        0     0        -7.6       0.0
# 87892 2020-12-31    23       회     13        0     0        -7.6       0.0
#
# [87893 rows x 8 columns]

# %%
food_weather['food'].unique()
# Out:
# array(['분식', '야식', '족발/보쌈', '찜탕', '치킨', '카페/디저트', '피자', '한식', '회',
#        '돈까스/일식', '패스트푸드', '아시안/양식', '도시락', '중식', '배달전문업체', '심부름'],
#       dtype=object)

# %%
index = food_weather[((food_weather.food == '배달전문업체')|(food_weather.food == '심부름'))].index

# %%
index
# Out:
# Int64Index([   90,   104,   119,   133,   147,   161,   188,   212,   245,
#               247,
#             ...
#             87778, 87780, 87794, 87809, 87811, 87825, 87840, 87854, 87868,
#             87882],
#            dtype='int64', length=8857)

# %%
food_weather = food_weather.drop(index)

# %%
food_weather['food'].unique()
# Out:
# array(['분식', '야식', '족발/보쌈', '찜탕', '치킨', '카페/디저트', '피자', '한식', '회',
#        '돈까스/일식', '패스트푸드', '아시안/양식', '도시락', '중식'], dtype=object)

# %%
len(food_weather)
# Out:
# 79036

# %%
food_weather.reset_index(drop=True)
# Out:
#             date  hour    food  count  Celsius  rain  celsius(C)  rain(mm)
# 0     2020-01-01     0      분식     13        0     0        -6.5       0.0
# 1     2020-01-01     0      야식     28        0     0        -6.5       0.0
# 2     2020-01-01     0   족발/보쌈     27        0     0        -6.5       0.0
# 3     2020-01-01     0      찜탕      3        0     0        -6.5       0.0
# 4     2020-01-01     0      치킨    103        0     0        -6.5       0.0
# ...          ...   ...     ...    ...      ...   ...         ...       ...
# 79031 2020-12-31    23  카페/디저트     32        0     0        -7.6       0.0
# 79032 2020-12-31    23   패스트푸드     25        0     0        -7.6       0.0
# 79033 2020-12-31    23      피자     24        0     0        -7.6       0.0
# 79034 2020-12-31    23      한식     28        0     0        -7.6       0.0
# 79035 2020-12-31    23       회     13        0     0        -7.6       0.0
#
# [79036 rows x 8 columns]

# %%
food_weather['date'] = food_weather['date'].dt.date

# %%
food_weather = food_weather.reset_index(drop=True)

# %%
food_weather
# Out:
#              date  hour    food  count  Celsius  rain  celsius(C)  rain(mm)
# 0      2020-01-01     0      분식     13        0     0        -6.5       0.0
# 1      2020-01-01     0      야식     28        0     0        -6.5       0.0
# 2      2020-01-01     0   족발/보쌈     27        0     0        -6.5       0.0
# 3      2020-01-01     0      찜탕      3        0     0        -6.5       0.0
# 4      2020-01-01     0      치킨    103        0     0        -6.5       0.0
# ...           ...   ...     ...    ...      ...   ...         ...       ...
# 79031  2020-12-31    23  카페/디저트     32        0     0        -7.6       0.0
# 79032  2020-12-31    23   패스트푸드     25        0     0        -7.6       0.0
# 79033  2020-12-31    23      피자     24        0     0        -7.6       0.0
# 79034  2020-12-31    23      한식     28        0     0        -7.6       0.0
# 79035  2020-12-31    23       회     13        0     0        -7.6       0.0
#
# [79036 rows x 8 columns]

# %%
food_weather = food_weather.drop(columns=['Celsius', 'rain'])
food_weather
# Out:
#              date  hour    food  count  celsius(C)  rain(mm)
# 0      2020-01-01     0      분식     13        -6.5       0.0
# 1      2020-01-01     0      야식     28        -6.5       0.0
# 2      2020-01-01     0   족발/보쌈     27        -6.5       0.0
# 3      2020-01-01     0      찜탕      3        -6.5       0.0
# 4      2020-01-01     0      치킨    103        -6.5       0.0
# ...           ...   ...     ...    ...         ...       ...
# 79031  2020-12-31    23  카페/디저트     32        -7.6       0.0
# 79032  2020-12-31    23   패스트푸드     25        -7.6       0.0
# 79033  2020-12-31    23      피자     24        -7.6       0.0
# 79034  2020-12-31    23      한식     28        -7.6       0.0
# 79035  2020-12-31    23       회     13        -7.6       0.0
#
# [79036 rows x 6 columns]

# %%
food_weather['date'].unique()
# Out:
# array([datetime.date(2020, 1, 1), datetime.date(2020, 1, 2),
#        datetime.date(2020, 1, 3), datetime.date(2020, 1, 4),
#        datetime.date(2020, 1, 5), datetime.date(2020, 1, 6),
#        datetime.date(2020, 1, 7), datetime.date(2020, 1, 8),
#        datetime.date(2020, 1, 9), datetime.date(2020, 1, 10),
#        datetime.date(2020, 1, 11), datetime.date(2020, 1, 12),
#        datetime.date(2020, 1, 13), datetime.date(2020, 1, 14),
#        datetime.date(2020, 1, 15), datetime.date(2020, 1, 16),
#        datetime.date(2020, 1, 17), datetime.date(2020, 1, 18),
#        datetime.date(2020, 1, 19), datetime.date(2020, 1, 20),
#        datetime.date(2020, 1, 21), datetime.date(2020, 1, 22),
#        datetime.date(2020, 1, 23), datetime.date(2020, 1, 24),
#        datetime.date(2020, 1, 25), datetime.date(2020, 1, 26),
#        datetime.date(2020, 1, 27), datetime.date(2020, 1, 28),
#        datetime.date(2020, 1, 29), datetime.date(2020, 1, 30),
# ...

# %%
food_weather['date'] = pd.to_datetime(food_weather['date'])

# %%
food_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79036 entries, 0 to 79035
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        79036 non-null  datetime64[ns]
#  1   hour        79036 non-null  int64
#  2   food        79036 non-null  object
#  3   count       79036 non-null  int64
#  4   celsius(C)  79036 non-null  float64
#  5   rain(mm)    79036 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(1)
# memory usage: 3.6+ MB

# %%
food_weather['day'] = food_weather['date'].dt.day_name()

# %%
cols = food_weather.columns.tolist()

# %%
cols
# Out:
# ['date', 'hour', 'food', 'count', 'celsius(C)', 'rain(mm)', 'day']

# %%
cols = [cols[0]] + [cols[-1]] + cols[1:6]

# %%
cols
# Out:
# ['date', 'day', 'hour', 'food', 'count', 'celsius(C)', 'rain(mm)']

# %%
food_weather = food_weather[cols]
food_weather
# Out:
#             date        day  hour    food  count  celsius(C)  rain(mm)
# 0     2020-01-01  Wednesday     0      분식     13        -6.5       0.0
# 1     2020-01-01  Wednesday     0      야식     28        -6.5       0.0
# 2     2020-01-01  Wednesday     0   족발/보쌈     27        -6.5       0.0
# 3     2020-01-01  Wednesday     0      찜탕      3        -6.5       0.0
# 4     2020-01-01  Wednesday     0      치킨    103        -6.5       0.0
# ...          ...        ...   ...     ...    ...         ...       ...
# 79031 2020-12-31   Thursday    23  카페/디저트     32        -7.6       0.0
# 79032 2020-12-31   Thursday    23   패스트푸드     25        -7.6       0.0
# 79033 2020-12-31   Thursday    23      피자     24        -7.6       0.0
# 79034 2020-12-31   Thursday    23      한식     28        -7.6       0.0
# 79035 2020-12-31   Thursday    23       회     13        -7.6       0.0
#
# [79036 rows x 7 columns]

# %%
food_weather = pd.read_csv('/content/drive/MyDrive/food_weather.csv')

# %%
food_weather['rain(mm)'].unique()
# Out:
# array([ 0. ,  0.1,  0.6,  0.5,  6.5,  2.4,  4.6,  7.2,  9. ,  7.1,  1.4,
#         0.2,  1.5,  0.8,  1.2,  3.2,  0.3,  1.7,  8.1,  3.5,  3.6,  3.1,
#         1.9,  6.2,  7.3,  0.7,  2.2,  0.4,  3.4,  3.7,  1.1,  1.6,  1.3,
#         1. ,  2.5,  2.6,  2.1,  1.8,  3.3,  0.9,  2.7,  4.1,  7.7,  6.6,
#         7.8,  2. ,  5. ,  5.6, 13.3, 10.8,  2.3, 12.4, 11. , 10.6,  3.8,
#         3.9,  2.8,  5.3, 14.6,  5.8,  5.2,  8.7, 10.7, 17.3, 16.6,  9.8,
#        15.1, 10.4, 26.9,  8. , 19. , 11.6,  3. ,  5.5,  2.9, 12.2,  8.9,
#        19.8, 15.3, 16.3, 21.6, 11.7,  6.1,  6.3,  6. , 17.9, 15.7, 15.5,
#         4.8,  4.7,  6.4, 28.6,  4.3, 18.2, 19.4, 21.8, 14.4, 22.8,  4.9,
#        16.8, 22.3,  5.1,  7.5, 22.1, 13.2,  8.6,  4. ,  4.5,  7. , 29.5,
#        11.5,  5.9, 42.1, 36.8])

# %%
food_weather_2 = food_weather

# %%
food_weather_day = food_weather_2.groupby(['day', 'food'])['count'].sum().reset_index()

# %%
food_weather_day
# Out:
#           day    food  count
# 0      Friday     도시락   2584
# 1      Friday  돈까스/일식  15483
# 2      Friday      분식  37136
# 3      Friday  아시안/양식   6078
# 4      Friday      야식  13172
# ..        ...     ...    ...
# 93  Wednesday  카페/디저트  23453
# 94  Wednesday   패스트푸드  30312
# 95  Wednesday      피자  14439
# 96  Wednesday      한식  26012
# 97  Wednesday       회   3678
#
# [98 rows x 3 columns]

# %%
Sunday = food_weather_day[food_weather_day['day'] == 'Sunday'][['food', 'count']]
Monday = food_weather_day[food_weather_day['day'] == 'Monday'][['food', 'count']]
Tuesday = food_weather_day[food_weather_day['day'] == 'Tuesday'][['food', 'count']]
Wednesday = food_weather_day[food_weather_day['day'] == 'Wednesday'][['food', 'count']]
Thursday = food_weather_day[food_weather_day['day'] == 'Thursday'][['food', 'count']]
Friday = food_weather_day[food_weather_day['day'] == 'Friday'][['food', 'count']]
Saturday = food_weather_day[food_weather_day['day'] == 'Saturday'][['food', 'count']]

# %%
Sunday
# Out:
#       food  count
# 42     도시락    593
# 43  돈까스/일식  17529
# 44      분식  41478
# 45  아시안/양식   8400
# 46      야식  12434
# 47   족발/보쌈  28356
# 48      중식  12649
# 49      찜탕   9418
# 50      치킨  92016
# 51  카페/디저트  40841
# 52   패스트푸드  37449
# 53      피자  22254
# 54      한식  33268
# 55       회   5443

# %%
import matplotlib as mpl  # 기본 설정 만지는 용도
import matplotlib.font_manager as fm  # 폰트 관련 용도

# %%
Sunday
# Out:
#       food  count
# 42     도시락    593
# 43  돈까스/일식  17529
# 44      분식  41478
# 45  아시안/양식   8400
# 46      야식  12434
# 47   족발/보쌈  28356
# 48      중식  12649
# 49      찜탕   9418
# 50      치킨  92016
# 51  카페/디저트  40841
# 52   패스트푸드  37449
# 53      피자  22254
# 54      한식  33268
# 55       회   5443

# %%
food_weather
# Out:
#        Unnamed: 0        date        day  ...  count celsius(C)  rain(mm)
# 0               0  2020-01-01  Wednesday  ...     13       -6.5       0.0
# 1               1  2020-01-01  Wednesday  ...     28       -6.5       0.0
# 2               2  2020-01-01  Wednesday  ...     27       -6.5       0.0
# 3               3  2020-01-01  Wednesday  ...      3       -6.5       0.0
# 4               4  2020-01-01  Wednesday  ...    103       -6.5       0.0
# ...           ...         ...        ...  ...    ...        ...       ...
# 79031       79031  2020-12-31   Thursday  ...     32       -7.6       0.0
# 79032       79032  2020-12-31   Thursday  ...     25       -7.6       0.0
# 79033       79033  2020-12-31   Thursday  ...     24       -7.6       0.0
# 79034       79034  2020-12-31   Thursday  ...     28       -7.6       0.0
# 79035       79035  2020-12-31   Thursday  ...     13       -7.6       0.0
#
# [79036 rows x 8 columns]

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
fm._rebuild()

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(Sunday))
plt.bar(x, Sunday['count'])
plt.xticks(x, Sunday['food'])
plt.title("Sunday")
plt.show()
# Out:
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
# ...

# %%
plt.figure(figsize=(14, 10))
x = np.arange(len(Monday))
plt.bar(x, Monday['count'])
plt.xticks(x, Monday['food'])
plt.title("Monday")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(14, 10))
x = np.arange(len(Tuesday))
plt.bar(x, Tuesday['count'])
plt.title("Tuesday")
plt.xticks(x, Tuesday['food'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(14, 10))
x = np.arange(len(Wednesday))
plt.bar(x, Wednesday['count'])
plt.xticks(x, Wednesday['food'])
plt.title("Wednesday")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(14, 10))
x = np.arange(len(Thursday))
plt.bar(x, Thursday['count'])
plt.xticks(x, Thursday['food'])
plt.title("Thursday")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(14, 10))
x = np.arange(len(Friday))
plt.bar(x, Friday['count'])
plt.xticks(x, Friday['food'])
plt.title("Friday")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(14, 10))
x = np.arange(len(Saturday))
plt.bar(x, Saturday['count'])
plt.xticks(x, Saturday['food'])
plt.title("Saturday")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
food_weather_hour = food_weather_2.groupby(['hour', 'food'])['count'].sum().reset_index()

# %%
food_weather_hour
# Out:
#      hour    food  count
# 0       0  돈까스/일식   1217
# 1       0      분식   1978
# 2       0  아시안/양식     93
# 3       0      야식   2992
# 4       0   족발/보쌈   2645
# ..    ...     ...    ...
# 286    23  카페/디저트   2352
# 287    23   패스트푸드   4327
# 288    23      피자   4362
# 289    23      한식   4513
# 290    23       회   1907
#
# [291 rows x 3 columns]

# %%
h_0 = food_weather_hour[food_weather_hour['hour'] == 0][['food', 'count']]
h_1 = food_weather_hour[food_weather_hour['hour'] == 1][['food', 'count']]
h_2 = food_weather_hour[food_weather_hour['hour'] == 2][['food', 'count']]
h_3 = food_weather_hour[food_weather_hour['hour'] == 3][['food', 'count']]
h_4 = food_weather_hour[food_weather_hour['hour'] == 4][['food', 'count']]
h_5 = food_weather_hour[food_weather_hour['hour'] == 5][['food', 'count']]
h_6 = food_weather_hour[food_weather_hour['hour'] == 6][['food', 'count']]
h_7 = food_weather_hour[food_weather_hour['hour'] == 7][['food', 'count']]
h_8 = food_weather_hour[food_weather_hour['hour'] == 8][['food', 'count']]
h_9 = food_weather_hour[food_weather_hour['hour'] == 9][['food', 'count']]
h_10 = food_weather_hour[food_weather_hour['hour'] == 10][['food', 'count']]
h_11 = food_weather_hour[food_weather_hour['hour'] == 11][['food', 'count']]
h_12 = food_weather_hour[food_weather_hour['hour'] == 12][['food', 'count']]
h_13 = food_weather_hour[food_weather_hour['hour'] == 13][['food', 'count']]
h_14 = food_weather_hour[food_weather_hour['hour'] == 14][['food', 'count']]
h_15 = food_weather_hour[food_weather_hour['hour'] == 15][['food', 'count']]
h_16 = food_weather_hour[food_weather_hour['hour'] == 16][['food', 'count']]
h_17 = food_weather_hour[food_weather_hour['hour'] == 17][['food', 'count']]
h_18 = food_weather_hour[food_weather_hour['hour'] == 18][['food', 'count']]
h_19 = food_weather_hour[food_weather_hour['hour'] == 19][['food', 'count']]
h_20 = food_weather_hour[food_weather_hour['hour'] == 20][['food', 'count']]
h_21 = food_weather_hour[food_weather_hour['hour'] == 21][['food', 'count']]
h_22 = food_weather_hour[food_weather_hour['hour'] == 22][['food', 'count']]
h_23 = food_weather_hour[food_weather_hour['hour'] == 23][['food', 'count']]

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_0))
plt.bar(x, h_0['count'])
plt.xticks(x, h_0['food'])
plt.title("0시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_1))
plt.bar(x, h_1['count'])
plt.xticks(x, h_1['food'])
plt.title("1시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_2))
plt.bar(x, h_2['count'])
plt.xticks(x, h_2['food'])
plt.title("2시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_3))
plt.bar(x, h_3['count'])
plt.xticks(x, h_3['food'])
plt.title("3시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_4))
plt.bar(x, h_4['count'])
plt.xticks(x, h_4['food'])
plt.title("4시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_5))
plt.bar(x, h_5['count'])
plt.xticks(x, h_5['food'])
plt.title("5시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_6))
plt.bar(x, h_6['count'])
plt.xticks(x, h_6['food'])
plt.title("6시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_7))
plt.bar(x, h_7['count'])
plt.xticks(x, h_7['food'])
plt.title("7시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_8))
plt.bar(x, h_8['count'])
plt.xticks(x, h_8['food'])
plt.title("8시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_9))
plt.bar(x, h_9['count'])
plt.xticks(x, h_9['food'])
plt.title("9시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_10))
plt.bar(x, h_10['count'])
plt.xticks(x, h_10['food'])
plt.title("10시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_11))
plt.bar(x, h_11['count'])
plt.xticks(x, h_11['food'])
plt.title("11시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_12))
plt.bar(x, h_12['count'])
plt.xticks(x, h_12['food'])
plt.title("12시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_13))
plt.bar(x, h_13['count'])
plt.xticks(x, h_13['food'])
plt.title("13시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_14))
plt.bar(x, h_14['count'])
plt.xticks(x, h_14['food'])
plt.title("14시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_15))
plt.bar(x, h_15['count'])
plt.xticks(x, h_15['food'])
plt.title("15시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_16))
plt.bar(x, h_16['count'])
plt.xticks(x, h_16['food'])
plt.title("16시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_17))
plt.bar(x, h_17['count'])
plt.xticks(x, h_17['food'])
plt.title("17시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_18))
plt.bar(x, h_18['count'])
plt.xticks(x, h_18['food'])
plt.title("18시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_19))
plt.bar(x, h_19['count'])
plt.xticks(x, h_19['food'])
plt.title("19시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_20))
plt.bar(x, h_20['count'])
plt.xticks(x, h_20['food'])
plt.title("20시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_21))
plt.bar(x, h_21['count'])
plt.xticks(x, h_21['food'])
plt.title("21시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46973 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_22))
plt.bar(x, h_22['count'])
plt.xticks(x, h_22['food'])
plt.title("22시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12, 8))
x = np.arange(len(h_23))
plt.bar(x, h_23['count'])
plt.xticks(x, h_23['food'])
plt.title("23시")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
#food_weather.to_csv('/content/drive/MyDrive/food_weather.csv')
